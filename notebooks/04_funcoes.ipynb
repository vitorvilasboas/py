# %% [markdown]
# ---
# # **Funções**
# ---
#
# * Funções são pequenas **partes de código** que realizam tarefas específicas;
# * Úteis para **executar** rotinas e **procedimentos repetitivos**;
# * Se tornam ainda mais necessárias à medida o programa fica maior;
# * Podem ou não receber entrada de dados (**parâmetros**);
# * Podem ou não retornar dados de saída (**retorno**).
#
# ```
# # Exemplos de funções já estudadas:
# print()
# input()
# len()
# range()
# count()
# append()
# ```
# O que é comum/padrão em todos os exemplos acima?
#
# ... Sim, os parênteses ()!
#
# Os parenteses servem para receber os **parâmetros** a serem usados pela função. Por exemplo, na função print() um parâmetro obrigatório é o que será impresso na tela (valor ou variável). Se a função não precisa de parâmetros, então os parenteses ficam vazios.

# %% [markdown]
# Estrutura Padrão de uma função em Python:

# %%
# CRIAÇÃO da função nomeFuncao
def nomeFuncao(parametros_da_funcao): # padrão de nomenclatura Cammelcase
  print(">> Aqui vão as rotinas de código executadas pela função. <<")
  return ''  # retorno do resultado da função (opcional)

# Uma vez criada, podemos CHAMAR a função
nomeFuncao()

# %%
def mostrar_nome():
  print("Vitor")
  # aki se define o uso da função
  # bloco da função


def calcular_soma(a, b):
  soma = a + b
  print(soma)
  ## quando vc precisar usar o resultado da função fora dela, vc precisa retornar esse resultado
  return soma

# %%
mostrar_nome()

num1 = int(input("Informe o 1o valor: "))
num2 = int(input("Informe o 2o valor: "))

#  são argumentos passados como parâmetro da função calcular_soma
# resultado = calcular_soma(5, 8)
resultado = calcular_soma(num1, num2)

print("Resultado: ", resultado)
media = resultado/2
print("Media: ", media)

# %%
p = 'valor_parametro'

# Se a função tiver parâmetros, devo enviá-los na chamada dentro dos parenteses (como argumentos)
nomeFuncao(p)

# %%
# Se a função tiver retorno, devo recebê-lo com uma variável
r = nomeFuncao(p)

# %% [markdown]
# #### Por que usar funções??

# %% [markdown]
# **Exemplo**: rotinas repetitivas sem o uso de funções:

# %%
t = input("Texto para formatação: ")
print("\n=================")
print(f"    {t} ")
print("=================\n")

t = input("Texto para formatação: ")
print("\n=================")
print(f"    {t} ")
print("=================\n")

t = input("Texto para formatação: ")
print("\n=================")
print(f"    {t} ")
print("=================\n")

# %% [markdown]
# agora o mesmo usando função

# %%
# cria função (única vez)
def imprime(tt):
  print("\n=================")
  print(f"    {t} ")
  print("=================\n")

t = input("Texto para formatação: ")
# chama função (quantas vezes desejar)
imprime(t)

imprime(t)

imprime(t)

# %% [markdown]
# modificando a função para receber o texto como PARÂMETRO

# %%
def imprime(t):
  print("\n=================")
  print(f"    {t} ")
  print("=================\n")


t = input("Texto para formatação: ")
imprime(t)

t = input("Texto para formatação: ")
imprime(t)

# %%
# Obs: o nome da variável enviada à função como argumento não precisa ser o mesmo nome do parâmetro da função

texto = input("Texto para formatação: ")
imprime(texto)

imprime(input("Texto para formatação: "))

# %% [markdown]
# **Exemplo**: Crie uma função que receba três valores fornecidos pelo usuário, calcule a média aritmética entre eles e retorne o resultado. Ao final mostre o valor da média na tela.

# %%
## SEM FUNÇÃO

a = 3
b = 5
c = 6
media = (a + b + c) / 3
print(f"Média entre {a}, {b} e {c} é {media}.")

a = 7
b = 5
c = 10
media = (a + b + c) / 3
print(f"Média entre {a}, {b} e {c} é {media}.")

a = 2
b = 3
c = 1
media = (a + b + c) / 3
print(f"Média entre {a}, {b} e {c} é {media}.")

# %%
## COM FUNÇÃO

def media_num(a, b, c):                              # se mais de um parâmetro, separe-os com virgula
  media = (a + b + c) / 3
  print(f"Média entre {a}, {b} e {c} é {media}.")


media_num(3, 5, 6)
media_num(7, 5, 10)
media_num(2, 3, 1)

# %%
num1 = float(input("1º valor: "))
num2 = float(input("2º valor: "))
num3 = float(input("3º valor: "))

media_num(num1, num2, num3)

# %%
media_num(float(input("1º valor: ")), float(input("2º valor: ")), float(input("3º valor: ")))

# %%
# COM FUNÇÃO COM RETORNO
# x = lambda a, b, c : (a + b + c) / 3

def media_num(a, b, c): 
  media = (a + b + c) / 3
  return media, soma, t                  # a função pode retornar um ou mais valores para serem usados no local onde foi chamada

# ao chamar a função com retorno deve-se receber o(s) retorno(s) usando variavel(is)
x1 = float(input("1º valor: "))
x2 = float(input("2º valor: "))
x3 = float(input("3º valor: "))
m = media_num(x1, x2, x3)

print(f"Média entre {x1}, {x2} e {x3} é {m}.")

# %%
import numpy as np
print(np.mean([float(input(f"{i}º valor: ")) for i in range(1, 4)]))

# %%
def media_num(a, b, c):  
  soma = a + b + c                       
  media = soma / 3
  return soma, media                    # a função pode retornar um ou mais valores para serem usados no local onde foi chamada


# ao chamar a função com retorno deve-se receber o(s) retorno(s) usando variavel(is)
s, m = media_num(float(input("1º valor: ")), float(input("2º valor: ")), float(input("3º valor: ")))

print(f"A Soma entre {a}, {b} e {c} é {s} e a Média entre eles é {m}.")

# %% [markdown]
# O objetivo do uso de funções é poder aplicar um mesmo conjunto de instruções em diferentes situações e contextos

# %%
def media_num(a, b, c):                              
  return (a + b + c) / 3     # é possível calcular e retornar na mesma linha

# Alturas
pedro = float(input("Informe a altura de Pedro: "))
maria = float(input("Informe a altura de Maria: "))
ester = float(input("Informe a altura de Ester: "))
media_alturas = media_num(pedro, maria, ester)
print(f"A altura média entre Pedro, Maria e Ester é {media_alturas} metros.")

# Distância
ab = float(input("Informe a distância da rota AB em Km: "))
bc = float(input("Informe a distância da rota BC em Km: "))
ca = float(input("Informe a distância da rota CA em Km: "))
rota_media = media_num(ab, bc, ca)
print(f"A distância média entre as rotas é igual a {rota_media} Km.")

# Notas
n1 = float(input("Informe a 1ª Nota do aluno: "))
n2 = float(input("Informe a 2ª Nota do aluno: "))
n3 = float(input("Informe a 3ª Nota do aluno: "))
media_notas = media_num(n1, n2, n3)
print(f"Média do aluno: {media_notas}")

# %%
for i in range(10, 100, 10):
  resultado = media_num(i, i*2, i**2)  # chamada da função com passagem de parâmetros
  print(f"Média entre {i}, {i*2} e {i**2}: {resultado}")

# %%
def verificar_maioridade(idade): # criação da função
  if idade >= 18:
    print("Você atingiu a maioridade.")
  else:
    print("Você ainda é menor de idade.")

idade = int(input("Informe sua idade: "))

verificar_maioridade(idade) # chamada da função
verificar_maioridade(45) # chamada da função
verificar_maioridade(7) # chamada da função

# %% [markdown]
# **Exemplo**: Crie uma função chamada area( ) que receba as dimensões de um terreno retangular (largura e comprimento), calcule e retorne a area do terreno.

# %%
def area_terreno(l, c):
  area = l * c 
  return area

# %%
largura = float( input("Informe a largura do terreno: ") )
comprimento = float( input("Informe o comprimento do terreno: ") )

resultado = area_terreno(largura, comprimento) # chamada da função

print(f"Área terreno = {resultado}")

# %% [markdown]
# **Exemplo**: Crie um script usando funções para encontrar as raizes de uma **equação do segundo grau** (ax² + bx + c = 0) a partir da fórmula de báscara:
#
# São três soluções possíveis conforme o valor do discriminante (delta)
# > delta > 0, a equação possui duas raízes reais e distintas
#
# > delta = 0, a equação possui raízes reais iguais
#
# > delta < 0, a equação não possui raízes reais

# %%
# delta = b**2 - 4*a*c
def calculo_delta(a, b, c):
  delta = b**2 - 4*a*c
  return delta

# X = (-b +- raiz(delta))/(2*a) 
def calculo_raizes(a, b, delta):
  import math
  if(delta >= 0):
    x1 = ( -b + math.sqrt(delta) ) / 2*a # math domain error
    x2 = ( -b - math.sqrt(delta) ) / 2*a
  else:
    x1, x2 = None, None
  return x1, x2

# %%
a = float(input("Informe o valor do coeficiente a: "))
b = float(input("Informe o valor do coeficiente b: "))
c = float(input("Informe o valor do coeficiente c: "))

delta = calculo_delta(a, b, c)

raiz1, raiz2 = calculo_raizes(a, b, delta)

if(raiz1 is None):
  print("Não existem raizes reais para os coeficiente informados.")
else:
  print(f"Raiz 1 = {raiz1} | Raiz 2 = {raiz2}")

# %% [markdown]
# **Exemplo**: Simule uma calculadora comum, capaz de realizar as quatro operações aritméticas básicas, a partir de dois números fornecidos pelo usuário. O programa deve ser capaz de realizar quantas operações o usuário quiser, dando a opção ao mesmo de encerrar o programa.

# %%
def soma(x, y):
  return x + y

def subtracao(x, y):
  return x - y

def multiplicacao(x, y):
  return x * y

def divisao(x, y):
  return x / y

def menu():
  opcao = input("""
  ############################
   Escolha uma operação: 
     [1] Soma
     [2] Subtração
     [3] Multiplicação
     [4] Divisão
     [outro] Sair
  ############################
  opção: 
  """)
  return opcao

def solicitaValores():
  a = int(input("Informe o 1o número inteiro: "))
  b = int(input("Informe o 2o número inteiro: "))
  return a, b

# %%
while True:
  operacao = menu()
  if operacao == '1':
    a, b = solicitaValores()
    resultado = soma(a, b)
  elif operacao == '2':
    a, b = solicitaValores()
    resultado = subtracao(a, b)
  elif operacao == '3':
    a, b = solicitaValores()
    resultado = multiplicacao(a, b)
  elif operacao == '4':
    a, b = solicitaValores()
    resultado = divisao(a, b)
  else:
    print("Saindo...")
    break;
  print(f"Resultado: {resultado}")

# %% [markdown]
# #### Empacotamento de parâmetros (*pacote) - parâmetro *args

# %% [markdown]
# **Exemplo:** Crie uma função que receba uma quantidade de parâmetros qualquer e retorne o número de parâmetros recebidos.

# %%
def quantidade(*parametros): # pacote de parâmetros recebido (por ponteiro *) tem um formato de lista
  print(parametros) # os parâmetros são posicionados como elementos de uma tupla - tuplas são imutáveis
  qtd = len(parametros)
  return qtd

qtd = quantidade(2, 3, 'vitor', 8, 9, 'mércia', 'teste')

print(f"Quantidade de parâmetros informada: {qtd}")

# %% [markdown]
# **Exemplo:** Faça um programa que use a função valorPagamento para determinar o valor a ser pago por uma prestação de uma conta. O programa deverá solicitar ao usuário o valor da prestação e o número de dias em atraso e passar estes valores para a função valorPagamento, que calculará o valor a ser pago e devolverá este valor ao programa que a chamou. O programa deverá então exibir o valor a ser pago na tela. Após a execução o programa deverá voltar a pedir outro valor de prestação e assim continuar até que seja informado um valor igual a zero para a prestação. Neste momento o programa deverá ser encerrado, exibindo o relatório do dia, que conterá a quantidade e o valor total de prestações pagas no dia. O cálculo do valor a ser pago é feito da seguinte forma. Para pagamentos sem atraso, cobrar o valor da prestação. Quando houver atraso, cobrar 3% de multa, mais 0,1% de juros por dia de atraso.

# %%
# docstrings = permitem a documentação de uma função 
def valorPagamento(prestacao, atraso):
  """
    Esta função calcula o valor para pagamento de uma prestação conforme o tempo de atraso
    Parâmetros:
    Entrada: prestacao (em reais), atraso (em dias)
    Saída: O calcula da prestação a pagar a partir dos juros e da multa obtidos pelo atraso
  """
  if (atraso == 0):
    return prestacao
  else:
    multa = prestacao * 0.03             # 0.03 representa 3% da prestação
    juros = atraso * 0.01 * prestacao    # 0.01 representa 1% da prestacao
    calculo = prestacao + multa + juros
    return calculo

somaPrestacoes = 0
qtdPrestacoes = 0

while True:
  prestacao = float(input("Informe o valor da prestação em reais: R$"))

  if prestacao == 0:
    print("Programa encerrado.")
    break;
  else:
    atraso = int(input("Informe a quantidade de dias em atraso: "))
    pagar = valorPagamento(prestacao, atraso)
    
    somaPrestacoes += pagar # incremento o calculo da prestação atual da soma de todas as prestações
    qtdPrestacoes += 1      # conto mais um calculo realizado
    
    print(f"Valor a pagar: {pagar}")

print(f"Número de prestações calculadas: {qtdPrestacoes}")
print(f"Valor total de prestações calculadas: R${somaPrestacoes}")

# %%
help(print)

# %%
## Calcular a exponenciação de um número

def exponencial(base, expoente=3):
  """
    Calcula a exponencial de um valor informado como parâmetro com base no expoente também fornecido...
  """
  return base**expoente

print( exponencial(3, 3) )

print( exponencial(3) )

# %% [markdown]
# **Exemplo**: Você está dirigindo um pouco rápido demais, e um policial para você. Escreva uma função para retornar um dos 3 resultados possíveis: "Sem multa", "Pequena multa" ou "Multa Grande". Se a sua velocidade for igual ou inferior a 60, o resultado é "Sem multa". Se a velocidade for entre 61 e 80 inclusive, o resultado é "Multa Pequena". Se a velocidade é de 81 ou mais, o resultado é "Multa Grande". A menos que seja seu aniversário (codificado como um valor booleano nos parâmetros da função) - em seu aniversário, sua velocidade pode ser 5 maior em todos os casos.

# %%
def capturar_velocidade(velocidade, aniversario):
    
    if aniversario:
        velocidade = velocidade - 5
    else:
        velocidade = velocidade
    
    if velocidade > 80:
        return 'Multa Pequena'
    elif velocidade > 60:
        return 'Multa Grande'
    else:
        return 'Sem Multa'

# %%
capturar_velocidade(65,False)

# %%
capturar_velocidade(81,False)

# %% [markdown]
# ## Funções lambda
# - declaração anônima
# - uso rápido

# %%
func = lambda a: a ** 2

# %%
func(2)

# %%
func(10)

# %%
x = [func(i) for i in [2, 3, 4]]

print(x)

# %%
media = lambda a, b: (a + b) / 2

print(media(2, 4))
print(media(5, 7))

# %% [markdown]
# #### Depuração no Pycharm:
#
#     Depurar == executar linha a linha e inspecionar variáveis
#     Breakpoint determina a linha em que a execução deve ser interrompida para inspeção
#
# Teclas de atalho:
#
#     F8      executa linha a linha após primeiro breakpoint (Step over)
#     Alt+F8  abre a view Evaluate expression (possibilita avaliar cada variável/objeto)
#     F7      próximo passo dentro de um bloco de instrução ou função (Step into)

# %%
a = 10
b = 1, 2, 3
x = [a, b]


def function1():
    print("qualquer texto")


def function2():
    function1()


def function3():
    function2()


def function4():
    f4 = 50
    function3()


def function5():
    function4()


function5()

print(a)
print(b)
print(x)
