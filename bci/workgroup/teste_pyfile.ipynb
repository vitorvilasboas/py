# %% [markdown]
# Montar GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Criar um novo arquivo .py

# %%
# %%writefile /content/drive/MyDrive/BCI_workgroup/labs/test.py
def func(a=2):
  print(f"Saída = {2}")
# Out:
# Writing /content/drive/MyDrive/BCI_workgroup/labs/test.py

# %% [markdown]
# Executar um arquivo .py

# %%
# !python /content/drive/MyDrive/BCI_workgroup/labs/learning.py
# Out:
# 0.5004499351483506 0.5004499351483506

# %% [markdown]
# Importar e executar função em arquivo .py

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/BCI_workgroup/labs')
from teste import func
func()
