# %%
# Montando o Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Confirmando a existência do arquivo
# !ls /content/gdrive/MyDrive/BCI_workgroup/*.py
# Out:
# /content/gdrive/MyDrive/BCI_workgroup/abc.py
# /content/gdrive/MyDrive/BCI_workgroup/bci_utils.py

# %%
# !cat '/content/gdrive/MyDrive/BCI_workgroup/Vitor.py'
# Out:
# cat: /content/gdrive/MyDrive/BCI_workgroup/Vitor.py: No such file or directory

# %%
# Adicionando o caminho do arquivo para importação ao path 
import sys
sys.path.append('/content/gdrive/MyDrive/BCI_workgroup/')

# %%
import abc
abc.teste()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-5aac70cc150e> in <module>()
#       1 import abc
# ----> 2 abc.teste()
#
# AttributeError: module 'abc' has no attribute 'teste'
